# %%
from bs4 import BeautifulSoup as soup
import requests

url = 'https://www.bestbuy.com/site/computer-cards-components/video-graphics-cards/abcat0507002.c?id=abcat0507002&qp=gpusv_facet%3DGraphics%20Processing%20Unit%20(GPU)~NVIDIA%20GeForce%20RTX%203060%5Egpusv_facet%3DGraphics%20Processing%20Unit%20(GPU)~NVIDIA%20GeForce%20RTX%203060%20Ti%5Egpusv_facet%3DGraphics%20Processing%20Unit%20(GPU)~NVIDIA%20GeForce%20RTX%203070%5Egpusv_facet%3DGraphics%20Processing%20Unit%20(GPU)~NVIDIA%20GeForce%20RTX%203080'

#Need to act as a user agent to look like a browser to gain access 
agent = {'User-Agent':'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/89.0.4389.114 Safari/537.36'}

page = requests.get(url,headers=agent).text
p_soup = soup(page,'html.parser')
print(p_soup.h1)
#grab each product
items = p_soup.findAll('li', {'class':'sku-item'})
print(len(items))
# Out:
# <h1 class="browse-title title">GPUs / Video Graphics Cards</h1>
# 24

# %%
print(items[0])
# Out:
# <li class="sku-item" data-sku-id="6429442"><div class="" data-track="[context:listRank=1]"><div><div class="None" data-version="21.0.4" id="shop-sku-list-item-15868367"><link href="/~assets/bby/_com/shop/sku-list-item/dist/client/client-c8d9017a4de09efab3d93acc19c6a233.css" rel="stylesheet"/><div class="shop-sku-list-item"><div class="list-item lv" data-sku-id="6429442"><div class="image-column"><a class="image-link" href="/site/nvidia-geforce-rtx-3070-8gb-gddr6-pci-express-4-0-graphics-card-dark-platinum-and-black/6429442.p?skuId=6429442"><img alt="NVIDIA GeForce RTX 3070 8GB GDDR6  PCI Express 4.0  Graphics Card - Dark Platinum and Black - Front_Zoom" class="product-image" src="https://pisces.bbystatic.com/image2/BestBuy_US/images/products/6429/6429442_sd.jpg;maxHeight=200;maxWidth=300" srcset="https://pisces.bbystatic.com/image2/BestBuy_US/images/products/6429/6429442_sd.jpg;maxHeight=300;maxWidth=450 1.5x"/></a></div><div class="right-column"><div class="information"><div class="embedded-badge"><div></div></div><div><div class="sku-title"><h4 class="sku-header"><a href="/site/nvidia-geforce-rtx-3070-8gb-gddr6-pci-express-4-0-graphics-card-dark-platinum-and-black/6429442.p?skuId=6429442">NVIDIA GeForce RTX 3070 8GB GDDR6  PCI Express 4.0  Graphics Card - Dark Platinum and Black</a></h4></div></div><div class="variation-info"><div class="sku-model"><div class="sku-attribute-title"><span class="attribute-title">Model:</span> <span class="sku-value">9001G1422510000</span></div> <div class="sku-attribute-title"><span class="attribute-title">SKU:</span> <span class="sku-value">6429442</span></div> </div><div class="ratings-reviews"><div><div class="None" data-version="2.2.24" id="user-generated-content-ugc-stats-62669463">
# <link href="https://www.bestbuy.com/~assets/bby/_com/user-generated-content/ugc-stats/dist/client/client-1110f4ac7db3aefa02090b32d5e42780.css" rel="stylesheet"/>
# <div class="user-generated-content-ugc-stats"><div class="appContainer size-l" data-reactroot=""><ul class="reviews-stats-list"><li class="ugc-stat customer-review-stats"><a data-track="stats: customerReviews" href="/site/nvidia-geforce-rtx-3070-8gb-gddr6-pci-express-4-0-graphics-card-dark-platinum-and-black/6429442.p?skuId=6429442#tabbed-customerreviews"><div class="ugc-ratings-reviews c-ratings-reviews-v4 c-ratings-reviews-v4-size-small"><p class="sr-only">User rating, 4.9 out of 5 stars with 1105 reviews.</p><i aria-hidden="true" class="c-stars-wrapper c-stars-wrapper-size-small"><span class="c-stars-container"><svg aria-hidden="true" fill="#C5CBD5" preserveaspectratio="xMinYMin slice" role="img" viewbox="0 0 87 16"><use href="/~assets/bby/_img/int/plsvgdef-frontend/svg/star-rating-empty.svg#star-rating-empty" xlink:href="/~assets/bby/_img/int/plsvgdef-frontend/svg/star-rating-empty.svg#star-rating-empty"></use></svg></span><span class="c-stars-container" style="width:86.26px;overflow:hidden"><svg aria-hidden="true" fill="#C28400" preserveaspectratio="xMinYMin slice" role="img" viewbox="0 0 87 16"><use href="/~assets/bby/_img/int/plsvgdef-frontend/svg/star-rating-border.svg#star-rating-border" xlink:href="/~assets/bby/_img/int/plsvgdef-frontend/svg/star-rating-border.svg#star-rating-border"></use></svg></span><span class="c-stars-container" style="width:85.26px;overflow:hidden"><svg aria-hidden="true" fill="#FFE000" preserveaspectratio="xMinYMin slice" role="img" viewbox="0 0 87 16"><use href="/~assets/bby/_img/int/plsvgdef-frontend/svg/star-rating.svg#star-rating" xlink:href="/~assets/bby/_img/int/plsvgdef-frontend/svg/star-rating.svg#star-rating"></use></svg></span></i><span aria-hidden="true" class="c-reviews-v4">(1,105)</span></div></a></li></ul></div></div>
# <script>
# 			if ('noModule' in HTMLScriptElement.prototype) {
# 				(function(document){
#
# 						var scriptEl = document.createElement('script');
# 						scriptEl.src = 'https://www.bestbuy.com/~assets/bby/_com/user-generated-content/ugc-stats/dist/client/client-7a153466bb5b38be70c9ff109aa8cea6.mjs';
# 						scriptEl.type = 'module';
# 						if (window.navigator.userAgent.indexOf("Edge") === -1) {
# 							scriptEl.async = false;
# 						}
# 						document.getElementById('user-generated-content-ugc-stats-62669463').appendChild(scriptEl);
#
# 				})(document);
# 			} else {
# 				(function(document){
#
# 						var scriptEl = document.createElement('script');
# 						scriptEl.src = 'https://www.bestbuy.com/~assets/bby/_com/user-generated-content/ugc-stats/dist/client/client-f796dbb93852544e910530a5764224cb.js';
# 						scriptEl.noModule = true;
# 						scriptEl.defer = true;
# 						if (window.navigator.userAgent.indexOf("Edge") === -1) {
# 							scriptEl.async = false;
# 						}
# 						document.getElementById('user-generated-content-ugc-stats-62669463').appendChild(scriptEl);
#
# 				})(document);
# 			}
# 		</script>
# <script>
# 			initializer.initializeComponent({"creatorNamespace":"user-generated-content","componentId":"ugc-stats","contractVersion":"v2","componentVersion":"2.2.24"}, 'user-generated-content-ugc-stats-62669463', "{\"app\":{\"device\":{\"isLarge\":true,\"isSmall\":false},\"instanceId\":\"user-generated-content-ugc-stats-62669463\",\"relativePdpUrl\":\"\\u002Fsite\\u002Fnvidia-geforce-rtx-3070-8gb-gddr6-pci-express-4-0-graphics-card-dark-platinum-and-black\\u002F6429442.p?skuId=6429442\",\"renderStyle\":\"smallStandard\",\"sku\":\"6429442\"},\"exp\":{\"expertStats\":{}},\"metaLayer\":{\"env_assets\":\"https:\\u002F\\u002Fwww.bestbuy.com\\u002F~assets\\u002Fbby\\u002F_com\",\"env_piscesUrl\":\"https:\\u002F\\u002Fpisces.bbystatic.com\",\"env_appServer\":\"https:\\u002F\\u002Fwww.bestbuy.com\"},\"qna\":{\"qnaStats\":{}},\"rnr\":{\"hideEmptyStars\":false,\"histogramsEnabled\":true,\"popoverEnabled\":true,\"reviewsLinkAction\":\"pdp\",\"reviewStats\":{\"sku\":\"6429442\",\"averageOverallRating\":{\"actual\":4.90316742081448,\"rounded\":4.9},\"topRated\":true,\"totalReviewCount\":1105,\"verifiedPurchaseCount\":1091,\"recommendedCount\":1080,\"recommendedPercent\":98,\"distributions\":[{\"distributionCode\":\"RATING\",\"items\":[{\"value\":1,\"count\":7,\"roundedPercent\":1,\"actualPercent\":0.6334841628959276},{\"value\":2,\"count\":2,\"roundedPercent\":0,\"actualPercent\":0.18099547511312217},{\"value\":3,\"count\":12,\"roundedPercent\":1,\"actualPercent\":1.085972850678733},{\"value\":4,\"count\":49,\"roundedPercent\":4,\"actualPercent\":4.4343891402714934},{\"value\":5,\"count\":1035,\"roundedPercent\":94,\"actualPercent\":93.66515837104072}]}],\"isReviewable\":true,\"rnrStandalonePage\":\"\\u002Fsite\\u002Freviews\\u002Fnvidia-geforce-rtx-3070-8gb-gddr6-pci-express-4-0-graphics-card-dark-platinum-and-black\\u002F6429442\",\"writeAReview\":\"\\u002Fsite\\u002Freviews\\u002Fsubmission\\u002F6429442?campaignId=PDP_&return=\",\"rnrAccordion\":\"\\u002Fsite\\u002Fnvidia-geforce-rtx-3070-8gb-gddr6-pci-express-4-0-graphics-card-dark-platinum-and-black\\u002F6429442.p?skuId=6429442#tabbed-customerreviews\"},\"syndicatedSummary\":[],\"variant\":\"\"}}", 'en-US');
# 		</script>
# </div></div></div></div><div></div><div></div></div><div class="price-block"><div class="sku-list-item-price"><div><div class="None" data-version="1.2114.2" id="pricing-price-38521228"><link href="https://assets.bbystatic.com/pricing/price/dist/client/client-8427af7808eeb8499bb67fac470b9fcf.css" rel="stylesheet"/><div class="pricing-price"><div class="pricing-price" data-csi-destinationzipcode="None" data-csi-tiercode="None" data-reactroot=""><div class="pricing-lib-price-8-2114-2 price-view-pb priceView-layout-medium" data-bold="false" data-bundledversion="8.2114.2" data-buyingoptionsonly="false" data-context="PLP-PriceBlock" data-disablebuyingoptions="true" data-disabledynamicgvppricing="false" data-disableensureassets="true" data-disablegiftwithpurchase="false" data-disablepricematchguarantee="false" data-disableupdateoncart="false" data-disableusepricewithcart="false" data-easyreplenishprice="false" data-enablealignright="false" data-enablemmtpricing="false" data-enablereference="false" data-fixedheight="false" data-ispricefetching="false" data-layout="medium" data-openboxcondition="" data-openboxfacet="false" data-pricewithbundle="false" data-randomgenerateduniqueid="9683158497240074" data-serverrendering="true" data-showgwp="false" data-skuid="6429442" data-suppressmemberbadges="false" data-suppressrestrictedprice="false" data-unlockedretailoption="false" data-version="8.2114.2" data-viewtype="price"><div class="pricing-price pricing-lib-price-8-2114-2 priceView-price" data-version="8.2114.2"><div class="priceView-price-match-guarantee"><span class="c-overlay-wrapper"><span class="overlayTrigger"><button aria-controls="price-match-guarantee-overlay-id-9683158497240074" aria-expanded="false" class="btn btn-link-unstyled v-medium price-match-guarantee-badge" type="button"> Price Match Guarantee</button></span></span></div><div class=""><div><div><div class="priceView-hero-price priceView-customer-price"><span aria-hidden="true">$499.99</span><span class="sr-only">Your price for this item is $<!-- -->499.99</span></div></div></div></div></div></div></div></div><script defer="" src="https://assets.bbystatic.com/pricing/price/dist/client/client-6a8f8591ab15168f044fa8f403d338f4.js"></script><script>initializer.initializeComponent({"creatorNamespace":"pricing","componentId":"price","contractVersion":"v1","componentVersion":"1.2114.2"}, "pricing-price-38521228", "{\"app\":{\"data\":{},\"instanceId\":\"pricing-price-38521228\",\"skuId\":\"6429442\",\"layout\":\"medium\",\"context\":\"PLP-PriceBlock\",\"openBoxCondition\":\"\",\"enableAlignRight\":false,\"enableReference\":false,\"enableMMTPricing\":false,\"openBoxFacet\":\"false\",\"priceDomain\":{\"skuId\":\"6429442\",\"regularPrice\":499.99,\"currentPrice\":499.99,\"priceEventType\":\"regular\",\"totalSavings\":0,\"totalSavingsPercent\":0,\"customerPrice\":499.99,\"isMAP\":false,\"isPriceMatchGuarantee\":true,\"gspUnitPrice\":499.99,\"financeOption\":{\"offerId\":\"384913\",\"financeCodeName\":\"12-Month Financing\",\"financeCode\":7,\"rank\":8,\"financeTerm\":12,\"monthlyPayment\":41.67},\"financeOptions\":[{\"offerId\":\"384913\",\"financeCodeName\":\"12-Month Financing\",\"financeCode\":7,\"rank\":8,\"financeTerm\":12,\"monthlyPayment\":41.67}],\"dotComDisplayStatus\":\"active\",\"locationId\":\"960\",\"currentAsOfDate\":\"2021-04-12T23:03:29 GMT\"},\"bundlePriceGVPServer\":{},\"mmtItemPriceServerData\":{},\"isPriceFetching\":false,\"priceWithBundle\":false,\"cookies\":{},\"disableDynamicGVPPricing\":false,\"configuration\":{\"allAccessModalNodeId\":\"all-access-modal-content\",\"gifts-with-purchase\":{\"disableOfferLinkService\":false,\"enableInstanceIdInjection\":true,\"features\":{\"clientSideRenderingOnly\":true,\"showNewGWPModalContent\":false}},\"bundle-and-save\":{\"features\":{\"showNewExperience\":true,\"showNewModalContent\":false}},\"customer-account-based-offer\":{\"features\":{\"showNewCABOModalContent\":false}},\"rnPriceBlock\":{\"showComplexGwp\":true,\"showRe ...
